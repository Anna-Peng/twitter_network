# %%
import pandas as pd
import numpy as np

import requests

from bs4 import BeautifulSoup

import tweepy

# %% [markdown]
# ----

# %% [markdown]
# # Scraping top 100 twitter tech experts

# %%
page = requests.get('https://www.zdnet.com/article/directory-100-technology-experts-on-twitter/')

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
names = []
user_names = []
for ol in soup.find_all('ol'):
    for x in ol.find_all('strong'):
        names.append(x.get_text())
    for x in ol.find_all('a', href=True):
        user_names.append(x.get_text())

# %%
experts = pd.DataFrame({'usernames': user_names, 'expert_names': names}, columns = [ 'expert_names', 'usernames'])
experts.head()
# Out:
#         expert_names      usernames
# 0     Chris Anderson        @chr1sa
# 1  Michael Arrington    @techcrunch
# 2      John Battelle  @johnbattelle
# 3   Veronica Belmont      @veronica
# 4    Randall Bennett      @randallb

# %% [markdown]
# ---

# %% [markdown]
# # Accessing twitter data

# %%
consumer_key = 'ctPrHdRrbU3HD4CbvQnYOzWNN'
consumer_secret = 'HPENaXC5uuX0IImsE2714focIOGPE1cyLEUSvTMaf7WAGv5Bnx'
# access_token = '1323179763888988161-PGUqXaJ7aoncBWo4QmN3OTDPIY6NHU'
# access_token_secret = 'PplXou5xCiRHqyZSb2r2PbzqRMYR2DIgQrpUMimoMbSyg'

# %%
def OAuth(key, secret, 
#           token, token_secret
         ):
    auth = tweepy.AppAuthHandler(key, secret)
#     auth.set_access_token(token, token_secret)
#  api = tweepy.API(auth,wait_on_rate_limit=True)
    
    api = tweepy.API(auth)
    return api

# %%
api = OAuth(consumer_key, consumer_secret)

# %% [markdown]
# ---

# %%
text_query = 'Tech'+ " -filter:retweets"
coordinates = '37.48164467541928,-122.15819183044557,50mi'
# until_date = '2020-11-20'
max_tweets = 150

# %%
def query_bytext(text, coord, m_tweets):
    tweets = tweepy.Cursor(api.search, q=text_query, 
                       geocode = coordinates, 
#                        until = until_date,
                       tweet_mode='extended').items(m_tweets)
    
    return tweets

# %%
tweets_bytext = query_bytext(text_query, coordinates, max_tweets)

# %% [markdown]
# ---

# %%
username = '@chr1sa'
max_tweets = 5

# %%
def query_byname(username, m_tweets):  
    tweets = tweepy.Cursor(api.user_timeline,id=username, tweet_mode='extended').items(m_tweets)
    
    return tweets

# %%
def iterate_through_users_tweets(_iterator):
    return [[tweet.full_text, tweet.created_at, tweet.id_str, tweet.favorite_count, 
                tweet.retweet_count, tweet.lang, tweet.in_reply_to_user_id_str, 
                tweet.is_quote_status, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, 
                tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, 
                tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, 
                tweet.user.statuses_count, tweet.user.listed_count, tweet.user.profile_image_url_https, 
                tweet.user.default_profile, tweet.user.default_profile_image] for tweet in _iterator]

# %%
pd.DataFrame([i for j in 
              [iterate_through_users_tweets(query_byname(username, 5)) for username in experts.usernames.to_list()[:3]] 
              for i in j])
# Out:
#                                                    0                   1   \
# 0   @pt @juliagalef We'll find out when the story ... 2020-11-27 17:30:25
# 1   @felixsalmon There's a theory of dreams that s... 2020-11-26 22:37:43
# 2   Echoes of my original "End of Theory" article ... 2020-11-26 21:14:18
# 3   @siliconsparrow Just funny that sci-fi films t... 2020-11-26 21:07:31
# 4   Moral of the story: don't get an electric moto... 2020-11-26 18:28:57
# 5   Facebook’s Libra could launch in January https... 2020-11-27 17:02:19
# 6   India sets rules for commissions, surge pricin... 2020-11-27 16:23:33
# 7   One thing is clear: there is still plenty of j... 2020-11-27 16:10:02
# 8   There's no 'hacker house' geared toward underg... 2020-11-27 16:01:18
# 9   Thanksgiving online shopping hits record $5.1B... 2020-11-27 15:53:27
# 10  Hey @zoom_us please share some interesting met... 2020-11-27 02:01:39
# 11            @therecount The laugh in the background 2020-11-26 03:28:30
# 12  @goppedpvteye I know! I had turned it off, but... 2020-11-25 15:59:09
# 13  @goppedpvteye Yup. That's all I know. Working ... 2020-11-25 15:29:37
# 14  OK Mac Twitter, riddle me this: Why did my mon... 2020-11-25 13:34:24
#
#                      2   3   4   5                    6      7   \
# 0   1332376243937767424   0   0  en              9571702  False
# 1   1332091189323911168  44   4  en             16399949  False
# 2   1332070198262730752   9   0  en                 None  False
# 3   1332068489704607745   1   0  en             91920942  False
# 4   1332028587751337984   7   3  en                 None   True
# 5   1332369171619917826  29  12  en                 None  False
# 6   1332359416839086081  12  10  en                 None  False
# 7   1332356016219033600  18   2  en                 None  False
# 8   1332353815690010624  22   4  en                 None  False
# 9   1332351839728263172  77  23  en                 None  False
# 10  1332142512346198018  14   0  en                 None  False
# 11  1331801980067581952   4   0  en  1087380412089987077  False
# 12  1331628501515055116   1   0  en             62617539  False
# 13  1331621068335964160   0   0  en             62617539  False
# 14  1331592070985871365   2   0  en                 None  False
#
#                 8             9   ...  \
# 0   Chris Anderson        chr1sa  ...
# 1   Chris Anderson        chr1sa  ...
# 2   Chris Anderson        chr1sa  ...
# 3   Chris Anderson        chr1sa  ...
# 4   Chris Anderson        chr1sa  ...
# 5       TechCrunch    TechCrunch  ...
# 6       TechCrunch    TechCrunch  ...
# 7       TechCrunch    TechCrunch  ...
# 8       TechCrunch    TechCrunch  ...
# 9       TechCrunch    TechCrunch  ...
# 10   John Battelle  johnbattelle  ...
# 11   John Battelle  johnbattelle  ...
# 12   John Battelle  johnbattelle  ...
# 13   John Battelle  johnbattelle  ...
# 14   John Battelle  johnbattelle  ...
#
#                                                    13    14        15    16  \
# 0   Suddenly realized that this bio does not have ...  True    192591  1581
# 1   Suddenly realized that this bio does not have ...  True    192591  1581
# 2   Suddenly realized that this bio does not have ...  True    192591  1581
# 3   Suddenly realized that this bio does not have ...  True    192591  1581
# 4   Suddenly realized that this bio does not have ...  True    192591  1581
# 5   Tech news with an emphasis on early stage star...  True  10143860   962
# 6   Tech news with an emphasis on early stage star...  True  10143860   962
# 7   Tech news with an emphasis on early stage star...  True  10143860   962
# 8   Tech news with an emphasis on early stage star...  True  10143860   962
# 9   Tech news with an emphasis on early stage star...  True  10143860   962
# 10  Co-founder @TheRecount, a founder of NewCo, so...  True    260954  2943
# 11  Co-founder @TheRecount, a founder of NewCo, so...  True    260954  2943
# 12  Co-founder @TheRecount, a founder of NewCo, so...  True    260954  2943
# 13  Co-founder @TheRecount, a founder of NewCo, so...  True    260954  2943
# 14  Co-founder @TheRecount, a founder of NewCo, so...  True    260954  2943
#
#        17      18      19                                                 20  \
# 0   16347   20500    8032  https://pbs.twimg.com/profile_images/131753567...
# 1   16347   20500    8032  https://pbs.twimg.com/profile_images/131753567...
# 2   16347   20500    8032  https://pbs.twimg.com/profile_images/131753567...
# 3   16347   20500    8032  https://pbs.twimg.com/profile_images/131753567...
# 4   16347   20500    8032  https://pbs.twimg.com/profile_images/131753567...
# 5    5851  218554  108586  https://pbs.twimg.com/profile_images/109606660...
# 6    5851  218554  108586  https://pbs.twimg.com/profile_images/109606660...
# 7    5851  218554  108586  https://pbs.twimg.com/profile_images/109606660...
# 8    5851  218554  108586  https://pbs.twimg.com/profile_images/109606660...
# 9    5851  218554  108586  https://pbs.twimg.com/profile_images/109606660...
# 10  17651   19109    6069  https://pbs.twimg.com/profile_images/605213208...
# 11  17651   19109    6069  https://pbs.twimg.com/profile_images/605213208...
# 12  17651   19109    6069  https://pbs.twimg.com/profile_images/605213208...
# 13  17651   19109    6069  https://pbs.twimg.com/profile_images/605213208...
# 14  17651   19109    6069  https://pbs.twimg.com/profile_images/605213208...
#
#        21     22
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
#
# [15 rows x 23 columns]

# %%
tweets_byname = query_byname(username, max_tweets)

# %% [markdown]
# ---

# %%
def generate_dataframe(tweets):
    tweets_list = [[tweet.full_text, tweet.created_at, tweet.id_str, tweet.favorite_count, 
                tweet.retweet_count, tweet.lang, tweet.in_reply_to_user_id_str, 
                tweet.is_quote_status, tweet.user.name, tweet.user.screen_name, tweet.user.id_str, 
                tweet.user.location, tweet.user.url, tweet.user.description, tweet.user.verified, 
                tweet.user.followers_count, tweet.user.friends_count, tweet.user.favourites_count, 
                tweet.user.statuses_count, tweet.user.listed_count, tweet.user.profile_image_url_https, 
                tweet.user.default_profile, tweet.user.default_profile_image] for tweet in tweets]

    return pd.DataFrame(tweets_list,columns=['tweet_text', 'tweet_datetime', 'tweet_id', 'tweet_favourites',
                                              'tweet_retweets', 'tweet_language', 'tweet_reply_user_id', 
                                              'tweet_quote', 'username', 'screenname', 'user_id',
                                              'user_location', 'user_url_inbio', 'user_description', 'user_verified',
                                              'user_followers', 'user_following', 'user_favourite_count',
                                              'user_status_count', 'user_lists', 'url_image',
                                              'default_theme', 'default_image'])

# %%
generate_dataframe(tweets_byname)
# Out:
#                                           tweet_text      tweet_datetime  \
# 0  @pt @juliagalef We'll find out when the story ... 2020-11-27 17:30:25
# 1  @felixsalmon There's a theory of dreams that s... 2020-11-26 22:37:43
# 2  Echoes of my original "End of Theory" article ... 2020-11-26 21:14:18
# 3  @siliconsparrow Just funny that sci-fi films t... 2020-11-26 21:07:31
# 4  Moral of the story: don't get an electric moto... 2020-11-26 18:28:57
#
#               tweet_id  tweet_favourites  tweet_retweets tweet_language  \
# 0  1332376243937767424                 0               0             en
# 1  1332091189323911168                44               4             en
# 2  1332070198262730752                 9               0             en
# 3  1332068489704607745                 1               0             en
# 4  1332028587751337984                 7               3             en
#
#   tweet_reply_user_id  tweet_quote        username screenname  ...  \
# 0             9571702        False  Chris Anderson     chr1sa  ...
# 1            16399949        False  Chris Anderson     chr1sa  ...
# 2                None        False  Chris Anderson     chr1sa  ...
# 3            91920942        False  Chris Anderson     chr1sa  ...
# 4                None         True  Chris Anderson     chr1sa  ...
#
#                                     user_description user_verified  \
# 0  Suddenly realized that this bio does not have ...          True
# 1  Suddenly realized that this bio does not have ...          True
# 2  Suddenly realized that this bio does not have ...          True
# 3  Suddenly realized that this bio does not have ...          True
# 4  Suddenly realized that this bio does not have ...          True
#
#   user_followers user_following  user_favourite_count  user_status_count  \
# 0         192591           1581                 16347              20500
# 1         192591           1581                 16347              20500
# 2         192591           1581                 16347              20500
# 3         192591           1581                 16347              20500
# 4         192591           1581                 16347              20500
#
#    user_lists                                          url_image  \
# 0        8032  https://pbs.twimg.com/profile_images/131753567...
# 1        8032  https://pbs.twimg.com/profile_images/131753567...
# 2        8032  https://pbs.twimg.com/profile_images/131753567...
# 3        8032  https://pbs.twimg.com/profile_images/131753567...
# 4        8032  https://pbs.twimg.com/profile_images/131753567...
#
#    default_theme  default_image
# 0          False          False
# 1          False          False
# 2          False          False
# 3          False          False
# 4          False          False
#
# [5 rows x 23 columns]

# %% [markdown]
# THINGS TO DO NEXT:
#
# - GET NON EXPERTS TWEETS
# - GET EXPERTS TWEETS (THROUGH NAMING FUNCTION)
#
#
# - WHAT ARE THE FEATURES THAT MAKE UP AN EXPERT?

# %% [markdown]
# **Resources**
#
# https://towardsdatascience.com/how-to-scrape-more-information-from-tweets-on-twitter-44fd540b8a1f
